# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojGhogare/LGMVIP-DATASCIENCE/blob/main/ImageToPencilSketchusingpython_ipnynp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perform By ManojGhogare

# %% [markdown]
# LGMVIP DataScience Task1

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/cartoon-art-g5fa4cf44f_1280.png")

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %%
image_invert = cv2.bitwise_not(img_gray)

# %%
plt.figure(figsize=(8,8))
plt.imshow(image_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %%
blur_image=cv2.GaussianBlur(image_invert,(21,21),sigmaX=0, sigmaY=0)

# %%
plt.figure(figsize=(8,8))
plt.imshow(blur_image,cmap="gray")
plt.axis("off")
plt.title("Blurry Image")
plt.show()

# %%
sketch = cv2.divide(img_gray, 255 - blur_image, scale=255)

# %%
plt.figure(figsize=(8,8))
plt.imshow(sketch,cmap="gray")
plt.axis("off")
plt.title("Final Sketch")
plt.show()
